# %%
import pandas as pd

# Mount Google Drive if your CSV file is stored there
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Specify the path to your CSV file
csv_path = '/content/drive/MyDrive/BDM Capstone/Processed Raw data/messo sale.csv'  # Update with your actual file path

# Read CSV file into a pandas DataFrame
df = pd.read_csv(csv_path)

# Display descriptive statistics for all columns
all_descriptive_stats = df.describe(include='all')

# Print the DataFrame with descriptive statistics
print(all_descriptive_stats)
print(df.columns)
# Out:
# <ipython-input-5-5fadf1afd9b0>:5: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_path)
#         order_date           year          Month            day  \
# count       195969  203987.000000  203987.000000  203987.000000
# unique          21            NaN            NaN            NaN
# top     2022-07-01            NaN            NaN            NaN
# freq         17392            NaN            NaN            NaN
# mean           NaN    2022.308294       5.902312      15.510351
# std            NaN       0.462903       2.923554       9.042979
# min            NaN    2021.000000       1.000000       1.000000
# 25%            NaN    2022.000000       4.000000       7.000000
# 50%            NaN    2022.000000       6.000000      16.000000
# 75%            NaN    2023.000000       8.000000      23.000000
# max            NaN    2023.000000      12.000000      31.000000
#
# ...

# %%
# Specify the path to your CSV file
csv_path = '/content/drive/MyDrive/BDM Capstone/Processed Raw data/raw taloir data.csv'  # Update with your actual file path

# Read CSV file into a pandas DataFrame
df = pd.read_csv(csv_path)

# Display descriptive statistics for all columns
all_descriptive_stats = df.describe(include='all')

# Print the DataFrame with descriptive statistics
all_descriptive_stats.T
# Out:
#                            count unique                top  freq         mean  \
# taloir_name                 4744     15       Munna Master   758          NaN
# date                        4744    472  25 September 2022    28          NaN
# m_day                     4744.0    NaN                NaN   NaN    15.356872
# month                       4744     12               June   736          NaN
# year                      4744.0    NaN                NaN   NaN  2022.559022
# type(out)                   2020      2               than  1953          NaN
# type(In)                    2724      6               long  2331          NaN
# quantity_out_(m)          2020.0    NaN                NaN   NaN   126.191386
# quantity_in_(Pc)          2724.0    NaN                NaN   NaN    46.406021
# in_or_out                   4744      2                 in  2724          NaN
# quantity_in_(m)           2724.0    NaN                NaN   NaN   110.226689
# ...

# %%
# Specify the path to your CSV file
csv_path = '/content/drive/MyDrive/BDM Capstone/Processed Raw data/Inventory data - Sheet1.csv'  # Update with your actual file path

# Read CSV file into a pandas DataFrame
df = pd.read_csv(csv_path)

# Display descriptive statistics for all columns
all_descriptive_stats = df.describe(include='all')

# Print the DataFrame with descriptive statistics
all_descriptive_stats.T
# Out:
#                        count unique   top freq       mean          std  \
# month                     16     12  June    2        NaN          NaN
# year                    16.0    NaN   NaN  NaN  2022.5625     0.512348
# Output                  16.0    NaN   NaN  NaN  5771.1875  3100.301732
# Input                   16.0    NaN   NaN  NaN   7017.375  3631.130676
# Variation               16.0    NaN   NaN  NaN  1246.1875  1345.703495
# Expected Opening Stock  16.0    NaN   NaN  NaN     4443.0  3107.823376
# Expected Closing Stock  16.0    NaN   NaN  NaN   4480.375  3121.817822
# Actual Open Stock       16.0    NaN   NaN  NaN  3234.1875  3561.985406
# Actual Closing Stock    16.0    NaN   NaN  NaN     2793.0     2633.122
#
#                            min      25%     50%      75%      max
# month                      NaN      NaN     NaN      NaN      NaN
# year                    2022.0   2022.0  2023.0   2023.0   2023.0
# ...

# %%
# Specify the path to your CSV file
csv_path = '/content/drive/MyDrive/BDM Capstone/Processed Raw data/Employee Survey - Sheet1.csv'  # Update with your actual file path

# Read CSV file into a pandas DataFrame
df = pd.read_csv(csv_path)

# Display descriptive statistics for all columns
all_descriptive_stats = df.describe(include='all')

# Print the DataFrame with descriptive statistics
all_descriptive_stats.T
# Out:
#                                                    count unique  \
# name                                                  14     14
# position                                              14      9
# age                                                 14.0    NaN
# gender                                                14      2
# Qualification                                         14      5
# Relative                                              14      2
# Wages/Salery                                        14.0    NaN
# Satisfaction with current role (1-5)                14.0    NaN
# Adequate Information about company's goal (0-No...  14.0    NaN
# Skill Utilization(1-5)                              14.0    NaN
# value of ideation(1-5)                              14.0    NaN
# Work Enviromenet comfortability(1-5)                14.0    NaN
# Oppertunity for professional growth (0-No, 1-Yes)   14.0    NaN
# Employe well being                                    14      1
# ...

# %%
# Specify the path to your CSV file
csv_path = '/content/drive/MyDrive/BDM Capstone/Processed Raw data/Aproximiated Financial Data - Sheet1.csv'  # Update with your actual file path

# Read CSV file into a pandas DataFrame
df = pd.read_csv(csv_path)

# Display descriptive statistics for all columns
all_descriptive_stats = df.describe(include='all')

# Print the DataFrame with descriptive statistics
all_descriptive_stats.T
# Out:
#                    count unique   top freq          mean             std  \
# month                 16     12  june    2           NaN             NaN
# year                16.0    NaN   NaN  NaN     2022.5625        0.512348
# secured loans       16.0    NaN   NaN  NaN  2565833.1875  1288945.062466
# loan interest rate  16.0    NaN   NaN  NaN        11.375         5.64358
# sundry creditors    16.0    NaN   NaN  NaN    6032081.25     1700953.338
# other liabilities   16.0    NaN   NaN  NaN     2008597.5   993879.549832
# Capital             16.0    NaN   NaN  NaN  6764050.5625   2599840.70486
# Cash in bank        16.0    NaN   NaN  NaN      324427.5   327919.959899
# Inventory           16.0    NaN   NaN  NaN  1038220.0625   743295.561638
# sundry debtors      16.0    NaN   NaN  NaN    2318792.25    773028.41219
# stock in trade      16.0    NaN   NaN  NaN     4550478.5  2344488.687673
# other assets        16.0    NaN   NaN  NaN     1518728.0   164393.785136
# ...

# %%
# Specify the path to your CSV file
csv_path = '/content/drive/MyDrive/BDM Capstone/Processed Raw data/Quantised Business Process and Operation Index - Sheet1.csv'  # Update with your actual file path

# Read CSV file into a pandas DataFrame
df = pd.read_csv(csv_path)

# Display descriptive statistics for all columns
all_descriptive_stats = df.describe(include='all')

# Print the DataFrame with descriptive statistics
all_descriptive_stats.T
# Out:
#                                         count unique      top freq  \
# month                                      21     12  January    2
# year                                     21.0    NaN      NaN  NaN
# Relative Production Efficiency(1-10)     21.0    NaN      NaN  NaN
# Relative Turnover(1-10)                  21.0    NaN      NaN  NaN
# Return Rate(1-5)                         21.0    NaN      NaN  NaN
# Customer Satisfaction(1-5)               21.0    NaN      NaN  NaN
# Quality Assurance Process(1-5)           21.0    NaN      NaN  NaN
# Relative Invetory Level(1-10)            21.0    NaN      NaN  NaN
# Employee Satisfaction(1-5)               21.0    NaN      NaN  NaN
# Supply Chain Effectiveness(1-5)          21.0    NaN      NaN  NaN
# Strategy Effectiveness(1-5)              21.0    NaN      NaN  NaN
# Business data Maintainance(1-10)         21.0    NaN      NaN  NaN
# Financial Performance(1-10)               0.0    NaN      NaN  NaN
# ...
